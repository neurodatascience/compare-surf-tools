# %% [markdown]
# # Exploratory code to compare CT processing pipelines
#     1. Dataset: ABIDE (https://riojournal.com/article/13726/)
#     2. Pipelines: ANTS, FreeSurfer, CIVET
#     3. Atlas: DKT
#     4. Plots: data distributoins, clusters, t-sne
#     5. Analysis: statistical models (e.g. OLS, ML classifiers)
#
# ## DX: 1 Autism, 2: Controls

# %%
# basic imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Paths

# %%
#data_dir = '/home/nikhil/projects/CT_reproduce/code/compare-surf-tools/data/'
data_dir = '/Users/nikhil/code/git_repos/compare-surf-tools/data/'

ants_file = 'ABIDE_ants_thickness_data.csv'
fs53_file = 'ABIDE_fs5.3_thickness.csv'
fs51_file = 'cortical_fs5.1_measuresenigma_thickavg.csv'  
subject_chk_file = 'subject_check.csv'
pheno_file = 'ABIDE_Phenotype.csv'

#outlier_file = data_dir + 'outliers/ageOutliersGroupPipeline_v4.csv'
outlier_file = '/Users/nikhil/Downloads/nonAdjOutliersGroupPipe.csv'
study_file = data_dir + 'standardized/study_data_df.csv'

#outlier_file = '/Users/nikhil/Downloads/ageOutliersGroupPipeline_v2.csv'
fs60_file_lh = '/Users/nikhil/Downloads/aparc_lh_thickness_table.txt'
fs60_file_rh = '/Users/nikhil/Downloads/aparc_rh_thickness_table.txt'

# %% [markdown]
# ## Read data

# %%
# Combine FS6.0 left and right data
fs_data_L = pd.read_csv(fs60_file_lh, delim_whitespace=True)
fs_data_L['SubjID'] = fs_data_L['lh.aparc.thickness'].str.split('/',expand=True)[1]
fs_data_L['SubjID'] = fs_data_L['SubjID'].str.split('.',expand=True)[0]
fs_data_L['SubjID'].str.split('_',expand=True)
fs_data_L
# Out:
#                                     lh.aparc.thickness  lh_bankssts_thickness  \
# 0    AbideVirtCollection/run1_Olin_0050127.out/sub-...                  2.870
# 1    AbideVirtCollection/run1_UM_1_0050359.out/sub-...                  2.702
# 2    AbideVirtCollection/run1_NYU_0051017.out/sub-0...                  2.548
# 3    AbideVirtCollection/run1_SBL_0051564.out/sub-0...                  2.221
# 4    AbideVirtCollection/run1_Yale_0050615.out/sub-...                  1.965
# 5    AbideVirtCollection/run1_KKI_0050794.out/sub-0...                  3.032
# 6    AbideVirtCollection/run1_UM_1_0050325.out/sub-...                  2.877
# 7    AbideVirtCollection/run1_KKI_0050820.out/sub-0...                  2.866
# 8    AbideVirtCollection/run1_CMU_b_0050655.out/sub...                  2.541
# 9    AbideVirtCollection/test3_OHSU_0050142.out/sub...                  2.776
# 10   AbideVirtCollection/run1_USM_0050474.out/sub-0...                  2.568
# 11   AbideVirtCollection/run1_Yale_0050612.out/sub-...                  2.866
# 12   AbideVirtCollection/run1_UM_1_0050322.out/sub-...                  2.552
# 13   AbideVirtCollection/run1_KKI_0050793.out/sub-0...                  2.856
# 14   AbideVirtCollection/run1_NYU_0050998.out/sub-0...                  2.549
# 15   AbideVirtCollection/run1_UCLA_2_0051294.out/su...                  2.646
# 16   AbideVirtCollection/run1_CMU_b_0050652.out/sub...                  2.697
# 858                          2.662                          2.871
# 859                          3.182                          2.492
# 860                          2.837                          2.943
# 861                          2.673                          2.964
# 862                          2.459                          2.771
# 863                          2.203                          2.496
#
#      lh_isthmuscingulate_thickness          ...            \
# 0                            2.562          ...
# 1                            2.964          ...
# 2                            2.270          ...
# 3                            1.996          ...
# 4                            2.679          ...
# 5                            2.409          ...
# 6                            3.133          ...
# 7                            2.265          ...
# 8                            2.286          ...
# 9                            2.552          ...
# 10                           2.775          ...
# 11                           2.458          ...
# 12                           2.330          ...
# 13                           2.606          ...
# 14                           2.320          ...
# 15                           2.519          ...
# 16                           2.806          ...
# 17                           2.269          ...
# 18                           2.787          ...
# 19                           2.981          ...
# 20                           2.584          ...
# 21                           2.564          ...
# 22                           2.783          ...
# 23                           2.310          ...
# 24                           2.259          ...
# 25                           2.145          ...
# 26                           2.257          ...
# 27                           2.477          ...
# 28                           2.667          ...
# 29                           2.543          ...
# ..                             ...          ...
# 834                          2.314          ...
# 835                          2.515          ...
# 836                          2.507          ...
# 837                          2.562          ...
# 838                          2.472          ...
# 839                          2.485          ...
# 840                          2.387          ...
# 841                          2.810          ...
# 842                          2.480          ...
# 843                          2.359          ...
# 844                          2.659          ...
# 845                          2.504          ...
# 846                          2.460          ...
# 847                          2.846          ...
# 848                          2.874          ...
# 849                          2.674          ...
# 850                          2.194          ...
# 851                          2.396          ...
# 852                          2.361          ...
# 853                          2.322          ...
# 854                          2.178          ...
# 855                          2.886          ...
# 856                          2.556          ...
# 857                          2.332          ...
# 858                          2.723          ...
# 859                          3.164          ...
# 860                          2.407          ...
# 861                          2.507          ...
# 862                          2.397          ...
# 863                          2.044          ...
#
#      lh_superiortemporal_thickness  lh_supramarginal_thickness  \
# 0                            3.057                       2.837
# 1                            2.661                       2.707
# 2                            2.743                       2.551
# 3                            2.535                       2.221
# 4                            2.275                       2.484
# 5                            3.108                       2.801
# 6                            2.314                       2.603
# 7                            2.963                       3.011
# 8                            2.904                       2.585
# 9                            2.949                       2.787
# 10                           2.855                       2.778
# 11                           2.270                       2.137
# 12                           2.449                       2.440
# 13                           3.140                       2.738
# 14                           2.821                       2.778
# 15                           2.963                       2.683
# 16                           2.982                       2.782
# 17                           2.776                       2.477
# 18                           3.002                       2.673
# 19                           3.053                       2.892
# 20                           2.774                       2.788
# 21                           2.904                       2.552
# 22                           2.920                       2.301
# 23                           3.066                       2.866
# 24                           2.821                       2.590
# 25                           2.559                       2.224
# 26                           2.959                       2.583
# 27                           3.076                       2.752
# 28                           3.366                       2.619
# 29                           2.965                       2.683
# ..                             ...                         ...
# 834                          2.805                       2.636
# 835                          2.987                       2.828
# 836                          2.628                       2.926
# 837                          3.214                       3.104
# 838                          2.883                       2.391
# 839                          3.025                       2.662
# 840                          2.667                       2.299
# 841                          3.095                       2.847
# 842                          2.958                       2.786
# 843                          3.062                       2.742
# 844                          3.023                       2.613
# 845                          2.912                       2.675
# 846                          2.717                       2.500
# 847                          3.026                       2.819
# 848                          2.756                       2.595
# 848                     2.60023            980627.0  1.202557e+06
# 849                     2.79019           1371559.0  1.638883e+06
# 850                     2.71671           1382417.0  1.914298e+06
# 851                     2.65293           1235414.0  1.549195e+06
# 852                     2.45630           1200842.0  1.540933e+06
# 853                     2.67537           1309385.0  1.626449e+06
# 854                     2.56301           1194976.0  1.516429e+06
# 855                     2.55702           1365219.0  1.764047e+06
# 856                     2.60772           1125817.0  1.443810e+06
# 857                     2.68180           1348288.0  1.691029e+06
# 858                     2.66607           1307686.0  1.567148e+06
# 859                     2.96847           1056605.0  1.353192e+06
# 860                     2.81556           1237768.0  1.380391e+06
# 861                     2.61391           1167839.0  1.454079e+06
# 862                     2.56481           1368323.0  1.735173e+06
# 863                     2.23278           1295344.0  1.726627e+06
#
#                     SubjID
# 0        run1_Olin_0050127
# 1        run1_UM_1_0050359
# 2         run1_NYU_0051017
# 3         run1_SBL_0051564
# 4        run1_Yale_0050615
# 5         run1_KKI_0050794
# 6        run1_UM_1_0050325
# 7         run1_KKI_0050820
# 8       run1_CMU_b_0050655
# 9       test3_OHSU_0050142
# 10        run1_USM_0050474
# 11       run1_Yale_0050612
# 12       run1_UM_1_0050322
# 13        run1_KKI_0050793
# 14        run1_NYU_0050998
# 15     run1_UCLA_2_0051294
# 16      run1_CMU_b_0050652
# 17    run1_Caltech_0051492
# 18        run1_USM_0050473
# 19       run1_Olin_0050120
# 20   run1_Stanford_0051167
# 21     run1_UCLA_1_0051201
# 22   run1_Leuven_2_0050750
# 23        run1_NYU_0051010
# 24        run1_NYU_0051148
# 25        run1_SBL_0051563
# 26        run1_USM_0050525
# 27        run1_NYU_0050996
# 28   run1_Leuven_2_0050722
# 29     run1_UCLA_1_0051273
# ..                     ...
# 834       run1_NYU_0051021
# 835      run1_Olin_0050111
# 836  run1_Stanford_0051187
# 837      run1_SDSU_0050214
# 838       run1_SBL_0051583
# 839       run1_KKI_0050816
# 840      run1_Yale_0050623
# 841       run1_KKI_0050773
# 842       run1_NYU_0050978
# 843       run1_USM_0050442
# 844       run1_USM_0050493
# 845       run1_NYU_0051105
# 846      run1_UM_1_0050314
# 847       run1_KKI_0050811
# 848      run1_Yale_0050624
# 849       run1_KKI_0050774
# 850   run1_Caltech_0051475
# 851       run1_USM_0050445
# 852       run1_USM_0050494
# 853       run1_NYU_0051102
# 854    run1_UCLA_1_0051237
# 855      run1_UM_1_0050368
# 856      run1_UM_2_0050426
# 857       run1_NYU_0051026
# 858      run1_Olin_0050116
# 859  run1_Stanford_0051180
# 860      run1_SDSU_0050213
# 861  run1_MaxMun_d_0051354
# 862       run1_USM_0050439
# 863       run1_SBL_0051584
#
# [864 rows x 39 columns]

# %%
ants_data = pd.read_csv(data_dir + ants_file, header=2)
fs53_data = pd.read_csv(data_dir + fs53_file)
fs51_data = pd.read_csv(data_dir + fs51_file)
subject_ckh = pd.read_csv(data_dir + subject_chk_file)
pheno = pd.read_csv(data_dir + pheno_file)
pheno = pheno.rename(columns={'Subject_ID':'SubjID'})
outlier_data = pd.read_csv(outlier_file)
#study_data = pd.read_csv(study_file)

# %%
sample_outliers = outlier_data[outlier_data['DX_GROUP']==1]['SubjID'].values[:100]

plot_df = outlier_data[outlier_data['SubjID'].isin(sample_outliers)]
plot_df['WAC'] = plot_df['sumHim']
print(plot_df.shape)
sns.set(font_scale=0.75)
with sns.axes_style("whitegrid"):
    g = sns.catplot(x='WAC',y='SubjID',col='pipeline',kind='strip',hue='outlier',
                    data=plot_df,palette='Set1',height=10,aspect=0.3,hue_order=[1,0])
    g.set(xscale="log");
# Out:
# /Users/nikhil/anaconda/envs/3D_UNet_clone/lib/python2.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# (300, 8)

# %%
print('dataframe shapes:')
print('pheno {}, ants {}, fs51 {}. fs53 {}'.format(pheno.shape, ants_data.shape, 
                                                   fs51_data.shape, fs53_data.shape))
print('\noutlier counts:')
pipe_outlier = {}
for pipe in set(outlier_data['pipeline']):
    p_o = outlier_data[(outlier_data['pipeline']==pipe) & (outlier_data['outlier']==1)]['SubjID'].values
    pipe_outlier[pipe] = p_o
    print('{} {}'.format(pipe, np.shape(p_o)[0]))
    
# outlier overlap
print(len(set(pipe_outlier['ants']) & set(pipe_outlier['fs51'])))
print(len(set(pipe_outlier['ants']) & set(pipe_outlier['fs53'])))
print(len(set(pipe_outlier['fs51']) & set(pipe_outlier['fs53'])))
# Out:
# dataframe shapes:
# pheno (1112, 102), ants (1101, 99), fs51 (1112, 74). fs53 (976, 74)
#
# outlier counts:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-8db48ac1b956> in <module>()
#       4 print('\noutlier counts:')
#       5 pipe_outlier = {}
# ----> 6 for pipe in set(outlier_data['pipeline']):
#       7     p_o = outlier_data[(outlier_data['pipeline']==pipe) & (outlier_data['outlier']==1)]['SubjID'].values
#       8     pipe_outlier[pipe] = p_o
#
# NameError: name 'outlier_data' is not defined

# %% [markdown]
# ## Create unified list of ROIs

# %%
# ANTS
ants_useful_cols = ['Structure Name']
ants_to_std_naming_dict = {}
ants_to_std_naming_dict['Structure Name'] = 'SubjID'
for roi in ants_data.columns:
    prefix = None
    name_split = roi.split(' ')
    if name_split[0] == 'left':
        prefix = 'L'
    if name_split[0] == 'right':
        prefix = 'R'

    if prefix is not None:
        ants_useful_cols.append(roi)
        std_name = prefix + '_' + ''.join(name_split[1:])
        ants_to_std_naming_dict[roi] = std_name

# %%
# FS
fs_useful_cols = ['SubjID']
fs_col_renames = {}
for roi in fs51_data.columns:
    prefix = None
    name_split = roi.split('_')
    if name_split[0] in ['L','R']:
        roi_rename = name_split[0] + '_' + name_split[1]
        fs_useful_cols.append(roi_rename)
        fs_col_renames[roi] = roi_rename
        
fs51_data = fs51_data.rename(columns=fs_col_renames)
fs53_data = fs53_data.rename(columns=fs_col_renames)

# %%
# standardize common naming, subjects, and columns
ants_data_std = ants_data[ants_useful_cols]
ants_data_std = ants_data_std.rename(columns=ants_to_std_naming_dict)

fs51_data_std = fs51_data[fs_useful_cols]
fs53_data_std = fs53_data[fs_useful_cols]
print('ANTS, FS 5.1, 5.3 data shapes {}, {}'.format(ants_data_std.shape, fs51_data_std.shape, fs53_data_std.shape))

# Common columns 
common_cols = list(set(ants_data_std.columns) & set(fs51_data_std.columns))
common_roi_cols = common_cols[:] #.copy()
common_roi_cols.remove('SubjID')
ants_data_std = ants_data_std[common_cols]
ants_data_std['pipeline'] = np.tile('ants',len(ants_data_std))
fs51_data_std = fs51_data_std[common_cols]
fs51_data_std['pipeline'] = np.tile('fs51',len(fs51_data_std))
fs53_data_std = fs53_data_std[common_cols]
fs53_data_std['pipeline'] = np.tile('fs53',len(fs53_data_std))

# Common subjects
common_subs = list(set(ants_data_std['SubjID'].values) & set(fs51_data_std['SubjID'].values) & set(fs53_data_std['SubjID'].values))
ants_data_std = ants_data_std[ants_data_std['SubjID'].isin(common_subs)]
fs51_data_std = fs51_data_std[fs51_data_std['SubjID'].isin(common_subs)]
fs53_data_std = fs53_data_std[fs53_data_std['SubjID'].isin(common_subs)]

print('After selecting common subjects {} and columns {}\nData shapes for ants {}, FS 5.1 {}, FS 5.3 {}'.format(len(common_subs), 
                                                                                                                len(common_cols),
                                                                                                                ants_data_std.shape,
                                                                                                                fs51_data_std.shape,
                                                                                                                fs53_data_std.shape))
# Out:
# ANTS, FS 5.1, 5.3 data shapes (1101, 90), (1112, 69)
# After selecting common subjects 975 and columns 63
# Data shapes for ants (975, 64), FS 5.1 (975, 64), FS 5.3 (975, 64)

# %%
# Add the outlier column for each pipeline df
ants_data_std = pd.merge(ants_data_std,outlier_data[outlier_data['pipeline']=='ants'][['SubjID','outlier','groupSowft','DX_GROUP']],
                        how='inner',on='SubjID')
#ants_data_std = ants_data_std.fillna(0)
fs51_data_std = pd.merge(fs51_data_std,outlier_data[outlier_data['pipeline']=='fs51'][['SubjID','outlier','groupSowft','DX_GROUP']],
                        how='inner',on='SubjID')
#fs51_data_std = fs51_data_std.fillna(0)
fs53_data_std = pd.merge(fs53_data_std,outlier_data[outlier_data['pipeline']=='fs53'][['SubjID','outlier','groupSowft','DX_GROUP']],
                        how='inner',on='SubjID')
#fs53_data_std = fs53_data_std.fillna(0)
print(ants_data_std.shape,fs51_data_std.shape,fs53_data_std.shape)
# Out:
# (975, 67) (975, 67) (975, 67)

# %%
# Melt the longform df for plotting... 
master_data_df = ants_data_std.append(fs51_data_std).append(fs53_data_std)

master_data_df_melt = pd.melt(master_data_df, id_vars=['SubjID','pipeline','outlier','groupSowft','DX_GROUP'], 
                              value_vars=common_roi_cols, var_name='ROI', value_name='thickness')

#master_data_df_melt[['ROI','measure']] = master_data_df_melt['ROI'].str.split('_',expand=True)[1:3]
# Out:
# /Users/nikhil/anaconda/envs/3D_UNet_clone/lib/python2.7/site-packages/pandas/core/indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %% [markdown]
# ## Plots: distributions

# %%
sns.set(font_scale=1.5)
with sns.axes_style("whitegrid"):
    g = sns.catplot(y='thickness', x='groupSowft', hue='DX_GROUP', kind='boxen', col='ROI', col_wrap=4, 
                    data=master_data_df_melt)

# %% [markdown]
# ## Filter df based on outliers and concat (horizontally)

# %%
include_sub_tags = [0,1] # if 0 implies exclude outliers; else use [0,1]  

ants_data_std_filtered = ants_data_std[ants_data_std['outlier'].isin(include_sub_tags)]
ants_data_corr = ants_data_std_filtered[common_cols]
ants_data_corr.columns = [str(col) + '_ants' for col in ants_data_corr.columns]
ants_data_corr = ants_data_corr.rename(columns={'SubjID_ants':'SubjID'})

fs51_data_std_filtered = fs51_data_std[fs51_data_std['outlier'].isin(include_sub_tags)]
fs51_data_corr = fs51_data_std_filtered[common_cols]
fs51_data_corr.columns = [str(col) + '_fs51' for col in fs51_data_corr.columns]
fs51_data_corr = fs51_data_corr.rename(columns={'SubjID_fs51':'SubjID'})

fs53_data_std_filtered = fs53_data_std[fs53_data_std['outlier'].isin(include_sub_tags)]
fs53_data_corr = fs53_data_std_filtered[common_cols]
fs53_data_corr.columns = [str(col) + '_fs53' for col in fs53_data_corr.columns]
fs53_data_corr = fs53_data_corr.rename(columns={'SubjID_fs53':'SubjID'})

concat_df = ants_data_corr.merge(fs51_data_corr, on='SubjID').merge(fs53_data_corr, on='SubjID')
print('shape after concat {}'.format(concat_df.shape))
# Out:
# shape after concat (975, 187)

# %%
#Before 
avg corr:
ants-fs51 0.427, ants-fs53 0.474, fs51-fs53 0.875
stdev corr:
ants-fs51 0.117, ants-fs53 0.118, fs51-fs53 0.036

# After
avg corr:
ants-fs51 0.427, ants-fs53 0.473, fs51-fs53 0.870
stdev corr:
ants-fs51 0.118, ants-fs53 0.120, fs51-fs53 0.038

# %% [markdown]
# ## Plots: correlations

# %%
corr = concat_df.corr()

# avg cross-correlations using diangonals (corrwith from pandas doesn't work)
ants_fs51 = corr.values[:62,62:124].diagonal()
ants_fs53 = corr.values[:62,124:].diagonal()
fs51_fs53 = corr.values[62:124,124:].diagonal()

print('avg corr:\nants-fs51 {:4.3f}, ants-fs53 {:4.3f}, fs51-fs53 {:4.3f}'.format(np.mean(ants_fs51),
                                                                   np.mean(ants_fs53),
                                                                   np.mean(fs51_fs53)))

print('stdev corr:\nants-fs51 {:4.3f}, ants-fs53 {:4.3f}, fs51-fs53 {:4.3f}'.format(np.std(ants_fs51),
                                                                   np.std(ants_fs53),
                                                                   np.std(fs51_fs53)))


# plot all pair-wise corrs (not really needed for seeing inter-pipeline comparisons)
# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)
#cmap = sns.diverging_palette(220, 20, n=7)

# Draw the heatmap with the mask and correct aspect ratio
# plt.figure(figsize=(20,20))
# sns.set(font_scale=1)
# sns.heatmap(corr, cmap=cmap, square=True, linewidths=.5,center=0)

# Plot roi-wise correlation
df_corr_pairs = pd.DataFrame(columns=['correlation','ROI','pipeline_pair'])
ants_fs51_df = pd.DataFrame(columns=['correlation','ROI','pipeline_pair'])
ants_fs51_df['correlation'] =  ants_fs51
ants_fs51_df['ROI'] = common_roi_cols
ants_fs51_df['pipeline_pair'] = np.tile('ants_fs51',62)

ants_fs53_df = pd.DataFrame(columns=['corr','ROI','pipeline_pair'])
ants_fs53_df['correlation'] =  ants_fs53
ants_fs53_df['ROI'] = common_roi_cols
ants_fs53_df['pipeline_pair'] = np.tile('ants_fs53',62)

fs51_fs53_df = pd.DataFrame(columns=['corr','ROI','pipeline_pair'])
fs51_fs53_df['correlation'] =  fs51_fs53
fs51_fs53_df['ROI'] = common_roi_cols
fs51_fs53_df['pipeline_pair'] = np.tile('fs51_fs53',62)


df_corr_pairs = df_corr_pairs.append(ants_fs51_df).append(ants_fs53_df).append(fs51_fs53_df)

roi_order = sorted(list(df_corr_pairs['ROI'].unique()))
sns.set(font_scale=1)
with sns.axes_style("whitegrid"):
    g = sns.catplot(x='correlation',y='ROI',hue='pipeline_pair',order=roi_order,
                data=df_corr_pairs,aspect=.5,height=10,kind='strip')
# Out:
# avg corr:
# ants-fs51 0.427, ants-fs53 0.474, fs51-fs53 0.875
# stdev corr:
# ants-fs51 0.117, ants-fs53 0.118, fs51-fs53 0.036
# /home/nikhil/anaconda3/envs/CT_reproduce/lib/python3.5/site-packages/pandas/core/frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %% [markdown]
# ## Plots: clusters

# %%
sns.set(style="white")
sns.set(font_scale=1)

similarity = 'euclidean'#'euclidean' #correlation
linkage = 'ward'

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

g1 = sns.clustermap(ants_data_std_filtered[common_roi_cols], row_cluster=True, col_cluster=False, metric = similarity, method=linkage, 
                   cmap=cmap, vmin=0, vmax=5, figsize=(20, 20),xticklabels=True, yticklabels=False)
g1.fig.suptitle('ants')

g2 = sns.clustermap(fs51_data_std_filtered[common_roi_cols], row_cluster=True, col_cluster=False, metric = similarity, method=linkage, 
                   cmap=cmap, vmin=0, vmax=5, figsize=(20, 20),xticklabels=True, yticklabels=False)
g2.fig.suptitle('fs5.1')

g3 = sns.clustermap(fs53_data_std_filtered[common_roi_cols], row_cluster=True, col_cluster=False, metric = similarity, method=linkage, 
                   cmap=cmap, vmin=0, vmax=5, figsize=(20, 20),xticklabels=True, yticklabels=False)
g3.fig.suptitle('fs5.3')
# Out:
# Text(0.5, 0.98, 'fs5.3')

# %%
# cluster memberships
# Very basic - assumes same order of cluster-class for each pipeline 
# TODO - pairwise memberships

import scipy.cluster.hierarchy as sch
import collections

def get_cluster_membership(_df,g,n_clusters):
    member_df = _df[['SubjID','pipeline']].copy()
    Z = g.dendrogram_row.linkage
    T = sch.fcluster(Z, n_clusters, 'maxclust')
    member_count = collections.Counter(T)
    print('Pipeline {}, cluster sizes {}'.format(member_df['pipeline'].values[0], member_count))
    member_df['membership'] = T
    return member_df

def get_cluster_overlap(df1,df2):
    #assert len(df1) == len(df2)
    concat_df = pd.merge(df1,df2,on='SubjID',how='inner')
    overlap = np.sum(concat_df['membership_x'].values  == concat_df['membership_y'].values)/len(concat_df)
    return overlap

# %%
n_cluster = 2
print('Sanity check: largest and smallest clusters should have same cluster_ids across pipelines\n')
      
cluster_df = pd.DataFrame()
C1_member = get_cluster_membership(ants_data_std_filtered, g1, n_cluster)
C2_member = get_cluster_membership(fs51_data_std_filtered, g2, n_cluster)
C3_member = get_cluster_membership(fs53_data_std_filtered, g3, n_cluster)

C1_C2_overlap = get_cluster_overlap(C1_member,C2_member)
C1_C3_overlap = get_cluster_overlap(C1_member,C3_member)
C2_C3_overlap = get_cluster_overlap(C2_member,C3_member)

print('\ncluster membership overlap: C1_C2 {:3.2f}, C1_C3 {:3.2f}, C2_C3 {:3.2f}'.format(C1_C2_overlap,C1_C3_overlap,C2_C3_overlap))
# Out:
# Sanity check: largest and smallest clusters should have same cluster_ids across pipelines
#
# Pipeline ants, cluster sizes Counter({2: 658, 1: 317})
# Pipeline fs51, cluster sizes Counter({2: 636, 1: 339})
# Pipeline fs53, cluster sizes Counter({2: 743, 1: 232})
#
# cluster membership overlap: C1_C2 0.60, C1_C3 0.63, C2_C3 0.85

# %% [markdown]
# ## Plot: t-SNE

# %%
from sklearn.manifold import TSNE
include_sub_tags = [0,1]

master_data_df_filtered = master_data_df[(master_data_df['outlier'].isin(include_sub_tags))]
X = master_data_df_filtered[common_roi_cols].values
print(master_data_df_filtered.shape)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-9480b8091971> in <module>()
#       2 include_sub_tags = [0,1]
#       3
# ----> 4 master_data_df_filtered = master_data_df[(master_data_df['outlier'].isin(include_sub_tags))]
#       5 X = master_data_df_filtered[common_roi_cols].values
#       6 print(master_data_df_filtered.shape)
#
# /Users/nikhil/anaconda/envs/3D_UNet_clone/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# /Users/nikhil/anaconda/envs/3D_UNet_clone/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# /Users/nikhil/anaconda/envs/3D_UNet_clone/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# /Users/nikhil/anaconda/envs/3D_UNet_clone/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /Users/nikhil/anaconda/envs/3D_UNet_clone/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'outlier'

# %%
X_embedded = TSNE(n_components=2,init='pca').fit_transform(X)
X_embedded.shape
# Out:
# (2925, 2)

# %%
# plot
embed_df = pd.DataFrame(columns=['x','y'],data=X_embedded)
embed_df['groupSowft'] = master_data_df_filtered['groupSowft'].values
embed_df['pipeline'] = master_data_df_filtered['pipeline'].values
embed_df['DX_GROUP'] = master_data_df_filtered['DX_GROUP'].values
embed_df['outlier'] = master_data_df_filtered['outlier'].values

embed_df['groupSowft'] = embed_df['groupSowft'].replace({1:'ants+control', 2:'fs5.1+control', 3:'fs5.3+control',
                                                         4:'ants+ASD', 5:'fs5.1+ASD', 6:'fs5.3+ASD'})

#embed_df['Outlier'] = embed_df['Outlier'].replace({1:'outlier', 0:'normal'})
embed_df['DX_GROUP'] = embed_df['DX_GROUP'].replace({1:'control', 2:'ASD'})

plt.figure(figsize=(10,20))
sns.set(font_scale=1) 
with sns.axes_style("whitegrid"):
    sns.scatterplot(x='x',y='y',hue='pipeline',style='DX_GROUP',
                    data=embed_df,palette="Set1")

# %%
master_data_df
# Out:
#      L_lingual  L_insula  R_parahippocampal  L_parsorbitalis  \
# 0     1.352624  3.501745           1.743960         1.857446
# 1     2.429622  3.872971           2.125246         2.444179
# 2     1.897829  2.894710           1.977099         1.735063
# 3     1.410067  3.931534           2.688929         2.696082
# 4     1.812642  3.168322           2.313743         2.124852
# 5     1.036574  3.119766           1.839390         1.759466
# 6     2.059929  4.277995           2.475622         2.765031
# 7     1.992327  4.695108           1.668841         2.847000
# 26               1.852606            1.783874         1.939999       1.071798
# 27               2.231173            2.151181         2.470748       1.620725
# 28               2.253603            1.898033         1.770742       0.752213
# 29               1.668790            1.577409         1.354808       0.748033
# ..                    ...                 ...              ...            ...
# 946              1.986000            2.394000         2.467000       1.942000
# 947              2.404000            2.098000         2.447000       2.086000
# 948              2.329000            2.181000         2.477000       1.835000
# 949              2.475000            3.115000         2.756000       2.211000
# 950              2.202000            2.483000         2.475000       1.771000
# 951              2.453000            2.699000         2.419000       1.926000
# 952              2.123000            2.731000         2.513000       2.044000
# 953              1.993000            2.260000         2.212000       1.739000
# 954              2.042000            2.341000         2.313000       1.766000
# 955              2.188000            2.720000         2.432000       1.970000
# 956              2.483000            2.471000         2.463000       2.012000
# 957              2.355000            2.446000         2.394000       1.947000
# 958              2.042000            2.216000         2.396000       2.015000
# 959              2.482000            2.310000         2.509000       2.203000
# 960              2.163000            2.747000         2.229000       1.916000
# 961              2.337000            2.320000         2.249000       1.865000
# 962              2.227000            2.495000         2.288000       1.790000
# 963              2.485000            2.401000         2.304000       2.250000
# 964              2.596000            2.272000         2.258000       1.934000
# 965              2.250000            2.574000         2.199000       1.876000
# 966              2.306000            2.131000         2.234000       1.858000
# 967              2.722000            2.349000         2.410000       1.969000
# 968              2.131000            2.477000         2.311000       1.759000
# 969              2.533000            1.961000         2.159000       1.750000
# 970              1.895000            2.342000         2.465000       1.903000
# 971              2.397000            2.391000         2.518000       1.820000
# 972              2.339000            2.734000         2.118000       1.951000
# 973              1.904000            2.445000         2.401000       1.968000
# 974              2.880000            2.186000         2.189000       1.896000
# 975              2.209000            2.304000         2.340000       1.889000
#
#      R_caudalmiddlefrontal  pipeline
# 0                 1.398267      ants
# 1                 2.327624      ants
# 2                 1.307526      ants
# 3                 2.106089      ants
# 4                 1.693380      ants
# 5                 1.089781      ants
# 6                 2.377697      ants
# 7                 2.541475      ants
# 8                 1.772686      ants
# 9                 1.971556      ants
# 10                1.597840      ants
# 11                2.037697      ants
# 12                1.433493      ants
# 13                1.328174      ants
# 14                1.528277      ants
# 15                2.462727      ants
# 16                1.536355      ants
# 17                2.495128      ants
# 18                2.316850      ants
# 19                1.660202      ants
# 20                1.332175      ants
# 21                1.616157      ants
# 22                1.877788      ants
# 23                1.627932      ants
# 24                2.315718      ants
# 25                1.641359      ants
# 26                1.259313      ants
# 27                2.217988      ants
# 28                1.594636      ants
# 29                1.119665      ants
# ..                     ...       ...
# 946               2.337000      fs53
# 947               2.720000      fs53
# 948               2.366000      fs53
# 949               2.923000      fs53
# 950               2.496000      fs53
# 951               2.317000      fs53
# 952               2.428000      fs53
# 953               2.259000      fs53
# 954               2.461000      fs53
# 955               2.842000      fs53
# 956               2.294000      fs53
# 957               2.655000      fs53
# 958               2.588000      fs53
# 959               2.652000      fs53
# 960               2.443000      fs53
# 961               2.305000      fs53
# 962               2.407000      fs53
# 963               2.629000      fs53
# 964               2.184000      fs53
# 965               2.303000      fs53
# 966               2.353000      fs53
# 967               2.622000      fs53
# 968               2.622000      fs53
# 969               2.258000      fs53
# 970               2.674000      fs53
# 971               2.614000      fs53
# 972               2.694000      fs53
# 973               2.717000      fs53
# 974               2.040000      fs53
# 975               2.307000      fs53
#
# [2925 rows x 64 columns]

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn import svm

useful_demograph = pheno[['SubjID','SEX','AGE_AT_SCAN','DX_GROUP']]
study_df = pd.merge(master_data_df, useful_demograph, how='left', on='SubjID')
print(study_df.shape)

pipe_pairs = {'ants' : ['ants'],
              'fs5.1' : ['fs51'],
              'fs5.3' : ['fs53']}

all_scores = pd.DataFrame(columns=['pipeline','Acc'])
scores = pd.DataFrame(columns=['pipeline','Acc'])
for i, pair in enumerate(pipe_pairs.keys()):
    ml_df = study_df[study_df['pipeline'].isin(pipe_pairs[pair])]
    X = ml_df[common_roi_cols].values
    y = pd.get_dummies(ml_df['DX_GROUP']).values[:,0]

    clf = svm.SVC(kernel='linear')
    acc = cross_val_score(clf, X, y, cv=RepeatedStratifiedKFold(n_splits=10, n_repeats=10))
    scores['pipeline'] = np.tile(pair,len(acc))
    scores['Acc'] = acc
    all_scores = all_scores.append(scores)

    print('DX {}, discriminative acc mean:{:4.3f}, stdev:{:4.3f}'.format(pair,np.mean(acc),np.std(acc)))
# Out:
# (2925, 67)
# DX fs5.1, discriminative acc mean:0.528, stdev:0.046
# DX fs5.3, discriminative acc mean:0.546, stdev:0.047
# DX ants, discriminative acc mean:0.559, stdev:0.044

# %% [markdown]
# ## ML classifier - sanity check

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn import svm

pipe_pairs = {'ants' : ['ants'],
              'fs5.1' : ['fs51'],
              'fs5.3' : ['fs53']}
# pipe_pairs = {'ants vs. fs5.1' : ['ants','fs51'],
#               'ants vs. fs5.3' : ['ants','fs53'],
#               'fs5.1 vs. fs5.3' : ['fs51','fs53']}

n_folds = 100
all_scores = pd.DataFrame(columns=['pipeline','Acc'])
scores = pd.DataFrame(columns=['pipeline','Acc'])
for i, pair in enumerate(pipe_pairs.keys()):
    ml_df = master_data_df_filtered[master_data_df_filtered['pipeline'].isin(pipe_pairs[pair])]
    X = ml_df[common_roi_cols].values
    y = pd.get_dummies(ml_df['DX_GROUP']).values[:,0]

    clf = svm.SVC(kernel='linear')
    acc = cross_val_score(clf, X, y, cv=RepeatedStratifiedKFold(n_splits=10, n_repeats=10))
    scores['pipeline'] = np.tile(pair,len(acc))
    scores['Acc'] = acc
    all_scores = all_scores.append(scores)

    print('DX {}, discriminative acc mean:{:4.3f}, stdev:{:4.3f}'.format(pair,np.mean(acc),np.std(acc)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-0b9436224fca> in <module>()
#      14 scores = pd.DataFrame(columns=['pipeline','Acc'])
#      15 for i, pair in enumerate(pipe_pairs.keys()):
# ---> 16     ml_df = master_data_df_filtered[master_data_df_filtered['pipeline'].isin(pipe_pairs[pair])]
#      17     X = ml_df[common_roi_cols].values
#      18     y = pd.get_dummies(ml_df['DX_GROUP']).values[:,0]
#
# NameError: name 'master_data_df_filtered' is not defined

# %%
DX ants, discriminative acc mean:0.563, stdev:0.046
DX fs5.3, discriminative acc mean:0.546, stdev:0.050
DX fs5.1, discriminative acc mean:0.533, stdev:0.043
# Out:
#   File "<ipython-input-35-d259b57c09e3>", line 1
#     DX ants, discriminative acc mean:0.563, stdev:0.046
#           ^
# SyntaxError: invalid syntax

# %%
x_order = ['ants','fs5.1','fs5.3']
sns.set(font_scale=1.5)
with sns.axes_style("whitegrid"):
    sns.catplot(y='Acc',x='pipeline',data=all_scores,kind='boxen',order=x_order,aspect=1.2,height=8)

# %% [markdown]
# # Sample Research Question
# * Predict age from cortical thickness

# %%
ml_df['DX_GROUP'].value_counts()
# Out:
# 2    523
# 1    452
# Name: DX_GROUP, dtype: int64

# %%
import statsmodels.api as sm

useful_demograph = pheno[['SubjID','SEX','AGE_AT_SCAN','FIQ','BMI']]
study_data_df = pd.merge(master_data_df_filtered, useful_demograph, how='left', on='SubjID')
print(study_data_df.shape)
# Out:
# (2925, 71)

# %% [markdown]
# ## OLS: age ~ cortical_thickness [+ sex + Dx]

# %%
# Lasso based multiple regression with all ROIs

dependent_var = 'AGE_AT_SCAN' #(either AGE_AT_SCAN of DX_GROUP)
results_df = pd.DataFrame(columns=list(range(n_pc)) + ['pipeline','metric'])
p = 0
n_pc = len(common_roi_cols)
for pipe in set(study_data_df['pipeline'].values):
    analysis_df = study_data_df[study_data_df['pipeline']==pipe]
    if dependent_var =='DX_GROUP':
        y = pd.get_dummies(analysis_df['DX_GROUP']).values[:,0]
    else:
        y = analysis_df[dependent_var].values
    
    # OLS or Logit
    t_val_list = []
    p_val_list = []
    R2_adj_list = []
    ci_val_list = []
    
    #lasso
    X_roi = analysis_df[common_roi_cols]
    
    if dependent_var =='DX_GROUP':
        X = np.hstack((X_roi, analysis_df[['SEX','AGE_AT_SCAN']].values))
        print(X.shape)
        model = sm.Logit(y,X)
        #results = model.fit()
    else:
        X = np.hstack((X_roi, analysis_df[['SEX','DX_GROUP']].values))
        print(X.shape)
        #X = sm.add_constant(X)
        model = sm.OLS(y,X)
        results = model.fit_regularized()
        
    
#     t_val = results.tvalues[:n_pc] # just for ROI
#     p_val = results.pvalues[:n_pc] # just for ROI
#     ci_val = results.conf_int()[n_pc]
#     t_val_list.append(t_val)
#     p_val_list.append(p_val)
#     ci_val_list.append(ci_val)

#     if dependent_var =='AGE_AT_SCAN':
#         r2_adj_val = results.rsquared_adj
#         R2_adj_list.append(r2_adj_val)

#     results_df.loc[p] = list(t_val_list) + [pipe,'t_val']
#     p+=1
#     results_df.loc[p] = list(p_val_list[0]) + [pipe,'p_val']
#     results_df.loc[p] = list(conf_int_val_list) + [pipe,'p_val']
#     p+=1

#     if dependent_var =='AGE_AT_SCAN':
#         results_df.loc[p] = list(R2_adj_list) + [pipe,'R2_adj']
#         p+=1
# Out:
# (929, 64)
# (915, 64)
# (946, 64)

# %%
results.params
# Out:
# array([ 3.41636774,  3.07734473, -0.16197665, -0.77535237, -1.13737303,
#        -0.13178115, -0.13285793,  1.36285852, -3.20807914,  0.64223363,
#        -0.96158882,  1.83996995,  0.34020105,  0.50787721, -0.90664593,
#        -0.20980202,  1.40391513, -0.07450878,  0.36525211, -2.84799675,
#        -0.5152971 ,  1.07820498,  1.90499875, -4.28711809,  1.68176591,
#         1.03219284, -0.62812525, -2.52295019,  2.64255792, -1.04286669,
#        -2.1430551 , -1.12499331,  1.47447575,  0.22557041, -1.90634909,
#         3.07875345,  0.5603517 ,  0.28109888, -1.21983978, -0.2983133 ,
#         0.34369344, -0.35277019,  0.91678033, -0.68351718,  0.74291485,
#        -0.31832567, -2.04664275,  1.4241274 ,  0.191755  , -0.95427988,
#        -1.43550318,  0.69770745, -1.69559651,  2.3746679 , -1.1383223 ,
#         1.27176333, -0.47064819, -0.014898  ,  0.4703623 , -0.88935111,
#        -0.25303873,  0.96252621,  2.06531515,  1.30242451])

# %%
# PCA based multiple regression with all ROIs
from sklearn.decomposition import PCA

dependent_var = 'AGE_AT_SCAN' #(either AGE_AT_SCAN of DX_GROUP)
results_df = pd.DataFrame(columns=list(range(n_pc)) + ['pipeline','metric'])
p = 0
n_pc = 10
for pipe in set(study_data_df['pipeline'].values):
    analysis_df = study_data_df[study_data_df['pipeline']==pipe]
    if dependent_var =='DX_GROUP':
        y = pd.get_dummies(analysis_df['DX_GROUP']).values[:,0]
    else:
        y = analysis_df[dependent_var].values
    
    # OLS or Logit
    t_val_list = []
    p_val_list = []
    R2_adj_list = []
    ci_val_list = []
    
    #pca
    X_roi = analysis_df[common_roi_cols]
    pca = PCA(n_components=n_pc)
    pca.fit(X_roi)
    print(pipe)
    print(pca.explained_variance_ratio_)
    X_pca = pca.transform(X_roi)
    
    if dependent_var =='DX_GROUP':
        X = np.hstack((X_pca, analysis_df[['SEX','AGE_AT_SCAN']].values))
        print(X.shape)
        model = sm.Logit(y,X)
    else:
        X = np.hstack((X_pca, analysis_df[['SEX','DX_GROUP']].values))
        print(X.shape)
        #X = sm.add_constant(X)
        model = sm.OLS(y,X)
        
    results = model.fit()
    t_val = results.tvalues[:n_pc] # just for ROI
    p_val = results.pvalues[:n_pc] # just for ROI
    ci_val = results.conf_int()[n_pc]
    t_val_list.append(t_val)
    p_val_list.append(p_val)
    ci_val_list.append(ci_val)

    if dependent_var =='AGE_AT_SCAN':
        r2_adj_val = results.rsquared_adj
        R2_adj_list.append(r2_adj_val)

#     results_df.loc[p] = list(t_val_list) + [pipe,'t_val']
#     p+=1
    results_df.loc[p] = list(p_val_list[0]) + [pipe,'p_val']
#     results_df.loc[p] = list(conf_int_val_list) + [pipe,'p_val']
    p+=1

#     if dependent_var =='AGE_AT_SCAN':
#         results_df.loc[p] = list(R2_adj_list) + [pipe,'R2_adj']
#         p+=1
# Out:
# ants
# [0.38799686 0.14946704 0.08306207 0.05664352 0.0461757  0.03326785
#  0.0260681  0.01966363 0.01694107 0.01568946]
# (929, 12)
# fs53
# [0.39386342 0.11489463 0.07838102 0.04870244 0.04332052 0.03168397
#  0.02668937 0.0190355  0.01748631 0.0154556 ]
# (915, 12)
# fs51
# [0.45474285 0.09913386 0.06722466 0.04430357 0.03830347 0.02860317
#  0.02327651 0.0218441  0.0157527  0.01482805]
# (946, 12)

# %%
results_df_melt = pd.melt(results_df, id_vars=['pipeline','metric'], value_vars=list(range(n_pc)),
                             var_name='PC', value_name='value')

hue_order = ['ants','fs51','fs53']
sns.set(font_scale=1)
with sns.axes_style("whitegrid"):
    g = sns.catplot(x = 'value', y='PC', hue='pipeline', col='metric', data=results_df_melt,
                    orient='h',kind='strip',aspect=0.5,height=10,sharex=False,hue_order=hue_order)

# %%
# For proof-of-concept, currently implemented as multiple regression instead of mass-univariate

dependent_var = 'DX_GROUP' #(either AGE_AT_SCAN of DX_GROUP)
results_df = pd.DataFrame(columns=common_roi_cols + ['pipeline','metric'])
p = 0
for pipe in set(study_data_df['pipeline'].values):
    analysis_df = study_data_df[study_data_df['pipeline']==pipe]
    if dependent_var =='DX_GROUP':
        y = pd.get_dummies(analysis_df['DX_GROUP']).values[:,0]
    else:
        y = analysis_df[dependent_var].values
    
    # OLS or Logit
    t_val_list = []
    p_val_list = []
    R2_adj_list = []
    ci_val_list = []
    
    for roi in common_roi_cols:
        if dependent_var =='DX_GROUP':
            X = analysis_df[[roi,'SEX','AGE_AT_SCAN']].values
            model = sm.Logit(y,X)
        else:
            X = analysis_df[[roi,'SEX','DX_GROUP']].values
            #X = sm.add_constant(X)
            model = sm.OLS(y,X)
        
        results = model.fit()
        t_val = results.tvalues[0] # just for ROI
        p_val = results.pvalues[0] # just for ROI
        ci_val = results.conf_int()[0]
        t_val_list.append(t_val)
        p_val_list.append(p_val)
        ci_val_list.append(ci_val)
        
        if dependent_var =='AGE_AT_SCAN':
            r2_adj_val = results.rsquared_adj
            R2_adj_list.append(r2_adj_val)
        
#     results_df.loc[p] = list(t_val_list) + [pipe,'t_val']
#     p+=1
    results_df.loc[p] = list(p_val_list) + [pipe,'p_val']
    p+=1

#     if dependent_var =='AGE_AT_SCAN':
#         results_df.loc[p] = list(R2_adj_list) + [pipe,'R2_adj']
#         p+=1
# Out:
# Optimization terminated successfully.
#          Current function value: 22.429337
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.313031
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.069072
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.305504
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.638475
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.930531
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.378134
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.984847
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.470823
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.274991
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.932763
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.882242
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.854619
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.454423
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.252256
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.934801
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.352282
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.360051
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.389538
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.596468
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.429782
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.336627
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.247165
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.151953
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.274911
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.082125
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.590249
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.674178
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 24.153601
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.331352
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.418334
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.725471
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.246861
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.598968
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.312150
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.759229
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.081691
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.232521
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.821430
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.516517
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.449710
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.630709
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.029986
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.808473
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.759549
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.377836
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.121991
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.306446
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.851798
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.065602
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.851602
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.498725
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.689558
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.771911
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.773623
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.790558
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.364821
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.660700
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.312859
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.641036
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.471471
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.533816
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.732354
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.972845
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.648807
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.230421
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.735335
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.968488
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.016252
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.782050
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.250165
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.203366
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.659445
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.389012
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 24.139100
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 24.134894
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.511228
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.694145
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.776097
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 24.234095
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.816023
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.704221
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.319585
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.617901
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.157407
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.090139
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.510530
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.323673
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.987809
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.640984
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.319593
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.971438
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.835411
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.963998
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.346138
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.040610
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.255959
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.569129
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.584811
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.951348
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.672759
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 24.097685
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.817882
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.252149
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.221085
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.968616
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.884619
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.012816
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.651395
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.649061
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.047709
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.377757
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.091842
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.934650
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.810401
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.829248
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.871907
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.424212
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.144380
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.691223
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.597725
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.247307
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.696682
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.406532
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.359664
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.635926
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.016426
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.199908
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.567399
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.026544
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.403573
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.647398
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.691592
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.357599
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.233147
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.914324
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.762082
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.587978
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.500723
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.816440
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.607010
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.395246
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.319519
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.454373
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.445548
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.768773
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.255304
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.071918
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.566836
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.114951
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.776318
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.458758
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.208723
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.238019
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.414399
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.931147
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.196629
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.513972
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.478164
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.750269
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 21.994630
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.333188
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.883628
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.430218
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.327579
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.512533
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.054159
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.590781
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.784418
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.392879
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.257342
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.642263
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.752144
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.143979
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.772411
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.758012
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.856803
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.768804
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.674659
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.502278
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 23.001411
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.612061
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.331929
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.749349
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.443784
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 22.629619
#          Iterations 4

# %%
results.summary()
# Out:
# /home/nikhil/anaconda3/envs/CT_reproduce/lib/python3.5/site-packages/statsmodels/base/model.py:488: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# /home/nikhil/anaconda3/envs/CT_reproduce/lib/python3.5/site-packages/statsmodels/base/model.py:488: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# /home/nikhil/anaconda3/envs/CT_reproduce/lib/python3.5/site-packages/statsmodels/discrete/discrete_model.py:3313: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.llf/self.llnull
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  975
# Model:                          Logit   Df Residuals:                      972
# Method:                           MLE   Df Model:                            2
# Date:                Tue, 18 Dec 2018   Pseudo R-squ.:                     inf
# Time:                        20:08:23   Log-Likelihood:                -22064.
# converged:                       True   LL-Null:                        0.0000
#                                         LLR p-value:                     1.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.1103      0.085      1.291      0.197      -0.057       0.278
# x2            -0.4663      0.174     -2.676      0.007      -0.808      -0.125
# x3             0.0051      0.007      0.707      0.480      -0.009       0.019
# ==============================================================================
# """

# %%
#Plot model results per pipeline

results_df_melt = pd.melt(results_df, id_vars=['pipeline','metric'], value_vars=common_roi_cols,
                             var_name='ROI', value_name='value')

hue_order = ['ants','fs51','fs53']
sns.set(font_scale=1)
with sns.axes_style("whitegrid"):
    g = sns.catplot(x = 'value', y='ROI', hue='pipeline', col='metric', data=results_df_melt,order=roi_order,
                    orient='h',kind='strip',aspect=0.5,height=10,sharex=False,hue_order=hue_order)
    g.set(xscale="log");
    g.ax.set_xlim(1e-2, 1)
    
#     g.map(sns.stripplot, size=10)

# %%
# Coe of variation across pipelines per ROI 
# List from John (Strict QC)
# CT differences based on age and Dx 
results_df_melt
# Out:
#     pipeline metric                         ROI         value
# 0       fs53  p_val                   L_lingual  3.273211e-02
# 1       ants  p_val                   L_lingual  2.469391e-03
# 2       fs51  p_val                   L_lingual  4.872763e-01
# 3       fs53  p_val                    L_insula  1.040440e-03
# 4       ants  p_val                    L_insula  1.935153e-01
# 5       fs51  p_val                    L_insula  3.597535e-02
# 6       fs53  p_val           R_parahippocampal  4.391121e-03
# 7       ants  p_val           R_parahippocampal  1.534636e-03
# 8       fs51  p_val           R_parahippocampal  4.521103e-01
# 9       fs53  p_val             L_parsorbitalis  4.492792e-01
# 10      ants  p_val             L_parsorbitalis  3.446649e-02
# 11      fs51  p_val             L_parsorbitalis  2.744388e-01
# 12      fs53  p_val          R_isthmuscingulate  2.111502e-07
# 13      ants  p_val          R_isthmuscingulate  1.317409e-07
# 14      fs51  p_val          R_isthmuscingulate  1.539871e-03
# 15      fs53  p_val                  L_fusiform  5.152791e-03
# 16      ants  p_val                  L_fusiform  2.955517e-04
# 17      fs51  p_val                  L_fusiform  3.010699e-01
# 18      fs53  p_val          L_inferiortemporal  1.828801e-02
# 19      ants  p_val          L_inferiortemporal  3.016606e-06
# 20      fs51  p_val          L_inferiortemporal  1.731091e-01
# 21      fs53  p_val             R_pericalcarine  1.105938e-02
# 22      ants  p_val             R_pericalcarine  1.272777e-04
# 23      fs51  p_val             R_pericalcarine  2.902565e-02
# 24      fs53  p_val  L_rostralanteriorcingulate  2.086103e-04
# 25      ants  p_val  L_rostralanteriorcingulate  2.694093e-01
# 26      fs51  p_val  L_rostralanteriorcingulate  1.471707e-02
# 27      fs53  p_val           L_parahippocampal  3.179615e-03
# 28      ants  p_val           L_parahippocampal  3.257680e-02
# 29      fs51  p_val           L_parahippocampal  3.725364e-01
# ..       ...    ...                         ...           ...
# 156     fs53  p_val                R_entorhinal  2.711610e-01
# 157     ants  p_val                R_entorhinal  1.085598e-06
# 158     fs51  p_val                R_entorhinal  7.909655e-02
# 159     fs53  p_val          L_isthmuscingulate  1.349254e-06
# 160     ants  p_val          L_isthmuscingulate  2.752213e-07
# 161     fs51  p_val          L_isthmuscingulate  3.586902e-03
# 162     fs53  p_val       R_medialorbitofrontal  8.716486e-01
# 163     ants  p_val       R_medialorbitofrontal  9.508721e-01
# 164     fs51  p_val       R_medialorbitofrontal  2.657002e-02
# 165     fs53  p_val                L_entorhinal  3.787382e-01
# 166     ants  p_val                L_entorhinal  3.066237e-06
# 167     fs51  p_val                L_entorhinal  1.377943e-01
# 168     fs53  p_val               R_paracentral  5.018382e-04
# 169     ants  p_val               R_paracentral  8.861258e-07
# 170     fs51  p_val               R_paracentral  8.366580e-03
# 171     fs53  p_val        L_transversetemporal  1.316158e-01
# 172     ants  p_val        L_transversetemporal  6.930993e-01
# 173     fs51  p_val        L_transversetemporal  9.921886e-01
# 174     fs53  p_val          R_parstriangularis  5.200658e-01
# 175     ants  p_val          R_parstriangularis  1.462518e-01
# 176     fs51  p_val          R_parstriangularis  2.642113e-01
# 177     fs53  p_val             R_supramarginal  1.503714e-04
# 178     ants  p_val             R_supramarginal  2.671530e-07
# 179     fs51  p_val             R_supramarginal  4.146462e-03
# 180     fs53  p_val               R_postcentral  5.616999e-04
# 181     ants  p_val               R_postcentral  3.596532e-05
# 182     fs51  p_val               R_postcentral  1.727244e-03
# 183     fs53  p_val       R_caudalmiddlefrontal  2.344481e-04
# 184     ants  p_val       R_caudalmiddlefrontal  4.367935e-10
# 185     fs51  p_val       R_caudalmiddlefrontal  2.525241e-02
#
# [186 rows x 4 columns]
